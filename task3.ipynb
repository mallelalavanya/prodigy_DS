# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('bank-additional-full.csv',sep=";")

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df['default'].value_counts()
# Out:
# default
# no         32588
# unknown     8597
# yes            3
# Name: count, dtype: int64

# %%
map={'yes':0,"no":1,"unknown":2}
df['default']=df['default'].map(map)

# %%
map={"yes":0,"no":1}
df['y']=df['y'].map(map)

# %%
df['job'].value_counts()
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %%
df=df.drop(['contact', 'month', 'day_of_week', 'duration', 'pdays'],axis=1)

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y        1      no   no
# 1       57     services  married          high.school        2      no   no
# 2       37     services  married          high.school        1     yes   no
# 3       40       admin.  married             basic.6y        1      no   no
# 4       56     services  married          high.school        1      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course        1     yes   no
# 41184   46  blue-collar  married  professional.course        1      no   no
# 41185   56      retired  married    university.degree        1     yes   no
# 41186   44   technician  married  professional.course        1      no   no
# 41187   74      retired  married  professional.course        1     yes   no
#
# ...

# %%
df[f'education'].value_counts()
# Out:
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64

# %%
 #categorical variables to dummy variables
df= pd.get_dummies(df, columns=['job', 'marital', 'education','poutcome','housing','loan',], drop_first=True,dtype=int)

# %%
df
# Out:
#        age  default    contact month day_of_week  duration  campaign  pdays  \
# 0       56       no  telephone   may         mon       261         1    999
# 1       57  unknown  telephone   may         mon       149         1    999
# 2       37       no  telephone   may         mon       226         1    999
# 3       40       no  telephone   may         mon       151         1    999
# 4       56       no  telephone   may         mon       307         1    999
# ...    ...      ...        ...   ...         ...       ...       ...    ...
# 41183   73       no   cellular   nov         fri       334         1    999
# 41184   46       no   cellular   nov         fri       383         1    999
# 41185   56       no   cellular   nov         fri       189         2    999
# 41186   44       no   cellular   nov         fri       442         1    999
# 41187   74       no   cellular   nov         fri       239         3    999
#
# ...

# %%
df['y']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 41183    0
# 41184    1
# 41185    1
# 41186    0
# 41187    1
# Name: y, Length: 41188, dtype: int64

# %%
#df.replace({True: 0, False:1}, inplace=True)

# %%
df
# Out:
#        age  default  campaign  previous  emp.var.rate  cons.price.idx  \
# 0       56        1         1         0           1.1          93.994
# 1       57        2         1         0           1.1          93.994
# 2       37        1         1         0           1.1          93.994
# 3       40        1         1         0           1.1          93.994
# 4       56        1         1         0           1.1          93.994
# ...    ...      ...       ...       ...           ...             ...
# 41183   73        1         1         0          -1.1          94.767
# 41184   46        1         1         0          -1.1          94.767
# 41185   56        1         2         0          -1.1          94.767
# 41186   44        1         1         0          -1.1          94.767
# 41187   74        1         3         1          -1.1          94.767
#
#        cons.conf.idx  euribor3m  nr.employed  y  ...  education_illiterate  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(['y'],axis=1)
y=df['y']

# %%
X
# Out:
#        age  default  campaign  previous  emp.var.rate  cons.price.idx  \
# 0       56        1         1         0           1.1          93.994
# 1       57        2         1         0           1.1          93.994
# 2       37        1         1         0           1.1          93.994
# 3       40        1         1         0           1.1          93.994
# 4       56        1         1         0           1.1          93.994
# ...    ...      ...       ...       ...           ...             ...
# 41183   73        1         1         0          -1.1          94.767
# 41184   46        1         1         0          -1.1          94.767
# 41185   56        1         2         0          -1.1          94.767
# 41186   44        1         1         0          -1.1          94.767
# 41187   74        1         3         1          -1.1          94.767
#
#        cons.conf.idx  euribor3m  nr.employed  job_blue-collar  ...  \
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 41183    0
# 41184    1
# 41185    1
# 41186    0
# 41187    1
# Name: y, Length: 41188, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train
# Out:
#        age  default  campaign  previous  emp.var.rate  cons.price.idx  \
# 7271    40        2         4         0           1.1          93.994
# 13284   25        1         1         0           1.4          93.918
# 11580   48        2        10         0           1.4          94.465
# 31835   43        1         2         0          -1.8          92.893
# 19551   49        1         1         0           1.4          93.444
# ...    ...      ...       ...       ...           ...             ...
# 12363   30        1         2         0           1.4          93.918
# 5695    50        1         2         0           1.1          93.994
# 8006    35        1         2         0           1.4          94.465
# 17745   44        2        21         0           1.4          93.918
# 17931   39        1         5         0           1.4          93.918
#
#        cons.conf.idx  euribor3m  nr.employed  job_blue-collar  ...  \
# ...

# %%
# Train the Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = clf.predict(X_test)

# Evaluation
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

#classification
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12357
#
#     accuracy                           1.00     12357
#    macro avg       1.00      1.00      1.00     12357
# weighted avg       1.00      1.00      1.00     12357
