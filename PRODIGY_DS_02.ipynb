# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import seaborn as sns

# %%
df=pd.read_csv('test.csv')
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df['Age'].isnull().value_counts()
# Out:
# Age
# False    332
# True      86
# Name: count, dtype: int64

# %%
df['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
mean=df['Age'].mean().round(2)

# %%
df['Age'].fillna(mean,inplace=True)

# %%
df['Age']
# Out:
# 0      34.50
# 1      47.00
# 2      62.00
# 3      27.00
# 4      22.00
#        ...
# 413    30.27
# 414    39.00
# 415    38.50
# 416    30.27
# 417    30.27
# Name: Age, Length: 418, dtype: float64

# %%
# Convert the 'Age' column from float to integer
df['Age'] = df['Age'].astype(int)

# %%
df['Age']
# Out:
# 0      34
# 1      47
# 2      62
# 3      27
# 4      22
#        ..
# 413    30
# 414    39
# 415    38
# 416    30
# 417    30
# Name: Age, Length: 418, dtype: int64

# %%
df['Cabin'].notnull().value_counts()
# Out:
# Cabin
# False    327
# True      91
# Name: count, dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex  Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Pclass   Name    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 0          False   False  False  False  False  False  False   False  False
# 1          False   False  False  False  False  False  False   False  False
# 2          False   False  False  False  False  False  False   False  False
# 3          False   False  False  False  False  False  False   False  False
# 4          False   False  False  False  False  False  False   False  False
# ..           ...     ...    ...    ...    ...    ...    ...     ...    ...
# 413        False   False  False  False  False  False  False   False  False
# 414        False   False  False  False  False  False  False   False  False
# 415        False   False  False  False  False  False  False   False  False
# 416        False   False  False  False  False  False  False   False  False
# 417        False   False  False  False  False  False  False   False  False
#
#      Embarked
# 0       False
# 1       False
# 2       False
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  418.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.191388    0.447368    0.392344   35.627188
# std     120.810458    0.841838   12.654104    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   23.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   30.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   35.750000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    int64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Embarked     418 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 32.8+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
df.sample(5)
# Out:
#      PassengerId  Pclass                              Name   Sex  Age  SibSp  \
# 337         1229       3                 Elias, Mr. Joseph  male   39      0
# 321         1213       3             Krekorian, Mr. Neshan  male   25      0
# 71           963       3                Minkoff, Mr. Lazar  male   21      0
# 108         1000       3  Willer, Mr. Aaron (Abi Weller")"  male   30      0
# 13           905       2              Howard, Mr. Benjamin  male   63      1
#
#      Parch  Ticket     Fare Embarked
# 337      2    2675   7.2292        C
# 321      0    2654   7.2292        C
# 71       0  349211   7.8958        S
# 108      0    3410   8.7125        S
# 13       0   24065  26.0000        S

# %%
df.nlargest(10,'Age')
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 13           905       2                               Howard, Mr. Benjamin
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 2            894       2                          Myles, Mr. Thomas Francis
# 142         1034       1                         Ryerson, Mr. Arthur Larned
# 193         1085       2                                  Lingane, Mr. John
#
#         Sex  Age  SibSp  Parch    Ticket      Fare Embarked
# 96   female   76      1      0     19877   78.8500        S
# ...

# %%
df.drop(columns=['Name', 'Ticket', 'PassengerId'], inplace=True)

# %%
df
# Out:
#      Pclass     Sex  Age  SibSp  Parch      Fare Embarked
# 0         3    male   34      0      0    7.8292        Q
# 1         3  female   47      1      0    7.0000        S
# 2         2    male   62      0      0    9.6875        Q
# 3         3    male   27      0      0    8.6625        S
# 4         3  female   22      1      1   12.2875        S
# ..      ...     ...  ...    ...    ...       ...      ...
# 413       3    male   30      0      0    8.0500        S
# 414       1  female   39      0      0  108.9000        C
# 415       3    male   38      0      0    7.2500        S
# 416       3    male   30      0      0    8.0500        S
# 417       3    male   30      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
df
# Out:
#      Pclass  Sex  Age  SibSp  Parch      Fare  Embarked
# 0         3    0   34      0      0    7.8292         2
# 1         3    1   47      1      0    7.0000         0
# 2         2    0   62      0      0    9.6875         2
# 3         3    0   27      0      0    8.6625         0
# 4         3    1   22      1      1   12.2875         0
# ..      ...  ...  ...    ...    ...       ...       ...
# 413       3    0   30      0      0    8.0500         0
# 414       1    1   39      0      0  108.9000         1
# 415       3    0   38      0      0    7.2500         0
# 416       3    0   30      0      0    8.0500         0
# 417       3    0   30      1      1   22.3583         1
#
# [418 rows x 7 columns]

# %% [markdown]
# # Data Visulisation

# %%
#scatter plot

# %%
df
# Out:
#      Pclass     Sex  Age  SibSp  Parch      Fare Embarked
# 0         3    male   34      0      0    7.8292        Q
# 1         3  female   47      1      0    7.0000        S
# 2         2    male   62      0      0    9.6875        Q
# 3         3    male   27      0      0    8.6625        S
# 4         3  female   22      1      1   12.2875        S
# ..      ...     ...  ...    ...    ...       ...      ...
# 413       3    male   30      0      0    8.0500        S
# 414       1  female   39      0      0  108.9000        C
# 415       3    male   38      0      0    7.2500        S
# 416       3    male   30      0      0    8.0500        S
# 417       3    male   30      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Age',y='Fare',data=df,hue='Sex')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
#rug plot
plt.figure(figsize=(12,6),dpi=200)
sns.rugplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
#hist
plt.figure(figsize=(10,8))
sns.histplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#kdeplot
plt.figure(figsize=(10,8))
sns.kdeplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#barplot
plt.figure(figsize=(6,4))
sns.barplot(x='Sex',y='Age',data=df,hue='Embarked')
plt.legend(bbox_to_anchor=(1.25,0.5))

# %%
#boxplot
plt.figure(figsize=(10,6))
sns.boxplot(y='Age',x='Sex',data=df,hue='Embarked')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#violin plot
plt.figure(figsize=(10,6))
sns.violinplot(y='Age',x='Sex',data=df,bw=1,split=True,inner='box')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
#boxenplot
plt.figure(figsize=(10,6))
sns.boxenplot(x='Embarked',y='Age',data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='Age'>

# %%
#swarmplot
plt.figure(figsize=(10,6))
sns.swarmplot(x='Embarked',y='Age',data=df,hue='Sex')
plt.legend(bbox_to_anchor=(1.25,0.5))

# %%
#jointplot
plt.figure(figsize=(10,6))
sns.jointplot(x='Age',y='Fare',data=df)

# %%
df
# Out:
#      Pclass     Sex  Age  SibSp  Parch      Fare Embarked
# 0         3    male   34      0      0    7.8292        Q
# 1         3  female   47      1      0    7.0000        S
# 2         2    male   62      0      0    9.6875        Q
# 3         3    male   27      0      0    8.6625        S
# 4         3  female   22      1      1   12.2875        S
# ..      ...     ...  ...    ...    ...       ...      ...
# 413       3    male   30      0      0    8.0500        S
# 414       1  female   39      0      0  108.9000        C
# 415       3    male   38      0      0    7.2500        S
# 416       3    male   30      0      0    8.0500        S
# 417       3    male   30      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
dat=df.drop(['Sex','Embarked'],axis=1)

# %%
plt.figure(figsize=(10,6))
sns.pairplot(data=dat)

# %%
print(df.isnull().sum())
mean=df['Fare'].mode()
mean
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64
# 0    7.75
# Name: Fare, dtype: float64

# %%
df['Fare'].fillna(7.75,inplace=True)

# %%
print(df.isnull().sum())

# %%
 #categorical variables to dummy variables
df = pd.get_dummies(df, columns=['Pclass', 'Sex', 'Embarked'], drop_first=True)
my_map={'male':0,'female':1}
df['Sex']=df['Sex'].map(my_map)

# %%
df['Embarked'].value_counts()
mymap={'S':0,'C':1,'Q':2}
df['Embarked']=df['Embarked'].map(mymap)

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('Embarked',axis=1)
Y=df['Embarked']

# %%
X
# Out:
#      Pclass  Sex  Age  SibSp  Parch     Fare
# 0         3    0   34      0      0   7.8292
# 1         3    1   47      1      0      7.0
# 2         2    0   62      0      0   9.6875
# 3         3    0   27      0      0   8.6625
# 4         3    1   22      1      1  12.2875
# ..      ...  ...  ...    ...    ...      ...
# 413       3    0   30      0      0     8.05
# 414       1    1   39      0      0    108.9
# 415       3    0   38      0      0     7.25
# 416       3    0   30      0      0     8.05
# 417       3    0   30      1      1  22.3583
#
# [418 rows x 6 columns]

# %%
Y
# Out:
# 0      2
# 1      0
# 2      2
# 3      0
# 4      0
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    1
# Name: Embarked, Length: 418, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %%
X_train
# Out:
#      Pclass  Sex  Age  SibSp  Parch     Fare
# 41        1    0   30      0      0    26.55
# 24        1    1   48      1      3  262.375
# 237       3    0   20      0      0    7.225
# 309       3    1   45      1      0  14.1083
# 154       3    0   13      4      2  31.3875
# ..      ...  ...  ...    ...    ...      ...
# 63        3    1   22      0      0    7.725
# 326       2    1   12      2      1     39.0
# 337       3    0   39      0      2   7.2292
# 11        1    0   46      0      0     26.0
# 351       2    0   25      0      0     10.5
#
# [292 rows x 6 columns]

# %%
X_test
# Out:
#      Pclass  Sex  Age  SibSp  Parch      Fare
# 257       3    0   28      0      0      8.05
# 330       2    1   48      0      2     36.75
# 314       1    1   55      0      0  135.6333
# 366       3    0   30      1      0   14.4583
# 363       3    0   27      0      0    8.6625
# ..      ...  ...  ...    ...    ...       ...
# 301       2    0   30      0      0   15.0458
# 408       3    1   30      0      0    7.7208
# 16        2    0   35      0      0     12.35
# 31        2    0   24      2      0      31.5
# 36        3    1   30      0      0      8.05
#
# [126 rows x 6 columns]

# %%
Y_train
# Out:
# 41     0
# 24     1
# 237    1
# 309    0
# 154    0
#       ..
# 63     2
# 326    0
# 337    1
# 11     0
# 351    0
# Name: Embarked, Length: 292, dtype: int64

# %%
Y_test
# Out:
# 257    0
# 330    0
# 314    1
# 366    1
# 363    0
#       ..
# 301    1
# 408    2
# 16     2
# 31     0
# 36     0
# Name: Embarked, Length: 126, dtype: int64
