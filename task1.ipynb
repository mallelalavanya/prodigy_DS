# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df=pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.notnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0      True            True                         True   True
# 1      True            True                         True   True
# 2      True            True                         True   True
# 3      True            True                         True   True
# 4      True            True                         True   True
# ..      ...             ...                          ...    ...
# 995    True            True                         True   True
# 996    True            True                         True   True
# 997    True            True                         True   True
# 998    True            True                         True   True
# 999    True            True                         True   True
#
#      test preparation course  math score  reading score  writing score
# 0                       True        True           True           True
# ...

# %%
#gender vs mathscore
sns.barplot(x='gender',y='math score',data=df)
plt.title('GENDER VS MATHSCORE' ,color='b')
# Out:
# Text(0.5, 1.0, 'GENDER VS MATHSCORE')

# %%
#math score 
warnings.simplefilter(action='ignore', category=FutureWarning)
# Create a histogram for the 'math score' column
sns.histplot(x='math score', bins=5,data=df)
plt.title(' HISTOGRAM ' ,color='b')
# Out:
# Text(0.5, 1.0, ' HISTOGRAM ')

# %%
sns.displot(df,x=df['reading score'],kde=False,color='r')
plt.title('reading score on histogram',color='b')
# Out:
# Text(0.5, 1.0, 'reading score on histogram')

# %%
sns.histplot(x='gender',data=df,bins=2,color='red')
plt.title("countplot based on gender",color='b')
# Out:
# Text(0.5, 1.0, 'countplot based on gender')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


score=df['writing score'].round(2)
sns.barplot(x=df['gender'], y=df['reading score'], data=df)
plt.title('gender vs reading score',color='b')

# Show the plot
# Out:
# Text(0.5, 1.0, 'gender vs reading score')

# %%
import seaborn as sns
import matplotlib.pyplot as plt



sns.barplot(x='gender', y='writing score', data=df)
plt.title('gender vs writing score',color='b')
# Show the plot
plt.show()

# %%
sns.histplot(x='lunch',data=df)
plt.title('histplot')
# Out:
# Text(0.5, 1.0, 'histplot')

# %%
sns.barplot(x='race/ethnicity',y='math score',data=df)
plt.title('race/ethnicity vs mathscore',color='b')
# Out:
# Text(0.5, 1.0, 'race/ethnicity vs mathscore')

# %%
sns.histplot(x='race/ethnicity',data=df,color='b')
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='Count'>

# %%
sns.barplot(x='race/ethnicity',y='reading score',data=df)
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='reading score'>
