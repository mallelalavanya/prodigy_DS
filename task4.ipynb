# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('twitter_training.csv')

# %%
df
# Out:
#        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# ...

# %%
df.isnull().sum()
# Out:
# 2401                                                       0
# Borderlands                                                0
# Positive                                                   0
# im getting on borderlands and i will murder you all ,    686
# dtype: int64

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
url = 'twitter_training.csv'  # Update with your local path

try:
    data = pd.read_csv(url, header=None, names=['id', 'entity', 'sentiment', 'text'], encoding='latin1')
    print("Dataset loaded successfully")
except Exception as e:
    print(f"Error loading dataset: {e}")


print(data.head())

print("Missing values per column:\n", data.isnull().sum())

print("Unique sentiment values:", data['sentiment'].unique())
# Out:
# Dataset loaded successfully
#      id       entity sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 text
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...
# Missing values per column:
#  id             0
# entity         0
# sentiment      0
# text         686
# dtype: int64
# Unique sentiment values: ['Positive' 'Neutral' 'Negative' 'Irrelevant']

# %%
# Plot the distribution of sentiment
plt.figure(figsize=(10, 6))
sns.countplot(x='sentiment', data=data, palette='viridis')
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# Group by 'entity' and 'sentiment' to analyze sentiment for different entities
entity_sentiment = data.groupby(['entity', 'sentiment']).size().unstack().fillna(0)

# Plot the sentiment for each entity
entity_sentiment.plot(kind='bar', stacked=True, figsize=(14, 7))
plt.title('Sentiment by Entity')
plt.xlabel('Entity')
plt.ylabel('Count')
plt.legend(title='Sentiment',bbox_to_anchor=(1.25,0.5))
plt.show()
